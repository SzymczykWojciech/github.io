# %% [markdown]
# <a href="https://colab.research.google.com/github/SzymczykWojciech/github.io/blob/main/Kopia_notatnika_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
m = float(input("Podaj długość w centymetrach"))
metry  = m/100
cale = m/2.54
print("Długość w metrach wynosi", metry)
print("Długość w calach wynosi", cale)
# Out:
# Podaj długość w centymetrach123
# Długość w metrach wynosi 1.23
# Długość w calach wynosi 48.425196850393704

# %%
wezly = float(input("Podaj prędkość w węzłach: "))

# Stała przeliczeniowa
kmh = wezly * 1.852
print("Prezdkość samolotu wynosi ", kmh)
# Out:
# Podaj prędkość w węzłach: 528
# Prezdkość samolotu wynosi  977.856
